# %%
import pandas as pd

# %%
csvpath = "clean_city_data.csv"

# %%
cities_df = pd.read_csv(csvpath)
cities_df
# Out:
#      City ID             City    Lat    Lng  Max Temp  Humidity  Cloudiness  \
# 0          0            India  20.00  77.00     72.39        61          23
# 1          1          Ushuaia -54.80 -68.30     50.00        71          75
# 2          2          Bhatkal  13.97  74.57     78.46        74          30
# 3          4     Longyearbyen  78.22  15.64     17.60        72           0
# 4          5         Hermanus -34.42  19.23     59.00        66           0
# ..       ...              ...    ...    ...       ...       ...         ...
# 558     2497            Matam  15.62 -13.33    102.20        20           0
# 559     2507         Santa Fe -31.63 -60.70     69.01        40         100
# 560     2508         Matagami  49.75 -77.63     22.24        90           0
# 561     2513           Bousso  10.48  16.71     90.03        29          33
# 562     2521  Manavālakurichi   8.13  77.30     84.20        79          40
#
#      Wind Speed Country        Date
# ...

# %%
html = cities_df.to_html(index=False)
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>City ID</th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>India</td>
#       <td>20.00</td>
#       <td>77.00</td>
#       <td>72.39</td>
#       <td>61</td>
#       <td>23</td>
#       <td>2.13</td>
#       <td>IN</td>
#       <td>1604077796</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>Ushuaia</td>
#       <td>-54.80</td>
#       <td>-68.30</td>
#       <td>50.00</td>
#       <td>71</td>
#       <td>75</td>
#       <td>28.86</td>
#       <td>AR</td>
#       <td>1604077571</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>Bhatkal</td>
#       <td>13.97</td>
#       <td>74.57</td>
#       <td>78.46</td>
# ...
